# %% [markdown]
# # Practice-Session 3

# %% [markdown]
# ### Find the players who took a shot after the 52nd minute in the African Cup of Nations final

# %%
from statsbombpy import sb
import warnings
#ignore by message
warnings.filterwarnings("ignore", message="credentials were not supplied")

import pandas as pd
import matplotlib.pyplot as plt
from mplsoccer import Pitch, VerticalPitch
from tqdm import tqdm

# %%
match_id = 3923881

# %%
df_events = sb.events(match_id=match_id)

# %%
df_events
# Out:
#      50_50 bad_behaviour_card ball_receipt_outcome ball_recovery_offensive  \
# 0      NaN                NaN                  NaN                     NaN
# 1      NaN                NaN                  NaN                     NaN
# 2      NaN                NaN                  NaN                     NaN
# 3      NaN                NaN                  NaN                     NaN
# 4      NaN                NaN                  NaN                     NaN
# ...    ...                ...                  ...                     ...
# 2694   NaN                NaN                  NaN                     NaN
# 2695   NaN                NaN                  NaN                     NaN
# 2696   NaN                NaN                  NaN                     NaN
# 2697   NaN                NaN                  NaN                     NaN
# 2698   NaN                NaN                  NaN                     NaN
#
#      ball_recovery_recovery_failure block_offensive carry_end_location  \
# 0                               NaN             NaN                NaN
# 1                               NaN             NaN                NaN
# 2                               NaN             NaN                NaN
# 3                               NaN             NaN                NaN
# 4                               NaN             NaN                NaN
# ...                             ...             ...                ...
# 2694                            NaN             NaN                NaN
# 2695                            NaN             NaN                NaN
# 2696                            NaN             NaN                NaN
# 2697                            NaN             NaN                NaN
# 2698                            NaN             NaN                NaN
#
#      clearance_aerial_won clearance_body_part clearance_head  ...  \
# 0                     NaN                 NaN            NaN  ...
# 1                     NaN                 NaN            NaN  ...
# 2                     NaN                 NaN            NaN  ...
# 3                     NaN                 NaN            NaN  ...
# 4                     NaN                 NaN            NaN  ...
# ...                   ...                 ...            ...  ...
# 2694                  NaN                 NaN            NaN  ...
# 2695                  NaN                 NaN            NaN  ...
# 2696                  NaN                 NaN            NaN  ...
# 2697                  NaN                 NaN            NaN  ...
# 2698                  NaN                 NaN            NaN  ...
#
#      substitution_outcome substitution_outcome_id   substitution_replacement  \
# 0                     NaN                     NaN                        NaN
# 1                     NaN                     NaN                        NaN
# 2                     NaN                     NaN                        NaN
# 3                     NaN                     NaN                        NaN
# 4                     NaN                     NaN                        NaN
# ...                   ...                     ...                        ...
# 2694             Tactical                   103.0  Jean Thierry Lazare Amani
# 2695                  NaN                     NaN                        NaN
# 2696                  NaN                     NaN                        NaN
# 2697                  NaN                     NaN                        NaN
# 2698                  NaN                     NaN                        NaN
#
#      substitution_replacement_id  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 2694                     23957.0
# 2695                         NaN
# 2696                         NaN
# 2697                         NaN
# 2698                         NaN
#
#                                                 tactics           team  \
# 0     {'formation': 343, 'lineup': [{'player': {'id'...        Nigeria
# 1     {'formation': 433, 'lineup': [{'player': {'id'...  Côte d'Ivoire
# 2                                                   NaN        Nigeria
# 3                                                   NaN  Côte d'Ivoire
# 4                                                   NaN  Côte d'Ivoire
# ...                                                 ...            ...
# 2694                                                NaN  Côte d'Ivoire
# 2695  {'formation': 343, 'lineup': [{'player': {'id'...        Nigeria
# 2696  {'formation': 4231, 'lineup': [{'player': {'id...        Nigeria
# 2697  {'formation': 433, 'lineup': [{'player': {'id'...  Côte d'Ivoire
# 2698  {'formation': 433, 'lineup': [{'player': {'id'...  Côte d'Ivoire
#
#      team_id     timestamp            type under_pressure
# 0        775  00:00:00.000     Starting XI            NaN
# 1       3374  00:00:00.000     Starting XI            NaN
# 2        775  00:00:00.000      Half Start            NaN
# 3       3374  00:00:00.000      Half Start            NaN
# 4       3374  00:00:00.000      Half Start            NaN
# ...      ...           ...             ...            ...
# 2694    3374  00:46:41.128    Substitution            NaN
# 2695     775  00:27:25.263  Tactical Shift            NaN
# 2696     775  00:42:35.583  Tactical Shift            NaN
# 2697    3374  00:42:45.687  Tactical Shift            NaN
# 2698    3374  00:46:53.679  Tactical Shift            NaN
#
# [2699 rows x 91 columns]

# %%
# convert to `timedelta` in order to make easy for time search
df_events.timestamp = pd.to_timedelta(df_events.timestamp)

# %%
df_goals_45 = df_events[
    (df_events["timestamp"] > "00:45:00") & (df_events["team"] == "Nigeria")  & (df_events["type"] == "Shot")
]
df_goals_45
# Out:
#      50_50 bad_behaviour_card ball_receipt_outcome ball_recovery_offensive  \
# 2489   NaN                NaN                  NaN                     NaN
#
#      ball_recovery_recovery_failure block_offensive carry_end_location  \
# 2489                            NaN             NaN                NaN
#
#      clearance_aerial_won clearance_body_part clearance_head  ...  \
# 2489                  NaN                 NaN            NaN  ...
#
#      substitution_outcome substitution_outcome_id substitution_replacement  \
# 2489                  NaN                     NaN                      NaN
#
#      substitution_replacement_id tactics     team team_id  \
# 2489                         NaN     NaN  Nigeria     775
#
#                   timestamp  type under_pressure
# 2489 0 days 00:50:12.092000  Shot            NaN
#
# [1 rows x 91 columns]

# %%
df_shot = df_events.loc[event_idx].squeeze()

# %%
# who shot?
df_shot.player
# Out:
# 'Alhassan Yusuf'

# %%
df_shot.shot_freeze_frame
# Out:
# [{'location': [102.8, 43.1],
#   'player': {'id': 43072, 'name': 'Jean-Philippe Krasso'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'teammate': False},
#  {'location': [109.7, 39.2],
#   'player': {'id': 36539, 'name': 'Wilfried Stephane Singo'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'teammate': False},
#  {'location': [107.4, 44.2],
#   'player': {'id': 7713, 'name': 'Obite Evan Ndicka'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'teammate': False},
#  {'location': [109.8, 42.0],
#   'player': {'id': 27133, 'name': 'Odilon Kossonou'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'teammate': False},
#  {'location': [108.9, 49.1],
#   'player': {'id': 10039, 'name': 'Ghislain Konan'},
#   'position': {'id': 6, 'name': 'Left Back'},
#   'teammate': False},
#  {'location': [104.2, 49.8],
#   'player': {'id': 7023, 'name': 'Franck Yannick Kessié'},
#   'position': {'id': 15, 'name': 'Left Center Midfield'},
#   'teammate': False},
#  {'location': [105.0, 39.7],
#   'player': {'id': 3017, 'name': 'Ibrahim Sangaré'},
#   'position': {'id': 10, 'name': 'Center Defensive Midfield'},
#   'teammate': False},
#  {'location': [102.4, 30.0],
#   'player': {'id': 212489, 'name': 'Oumar Diakité'},
#   'position': {'id': 17, 'name': 'Right Wing'},
#   'teammate': False},
#  {'location': [94.7, 40.7],
#   'player': {'id': 23957, 'name': 'Jean Thierry Lazare Amani'},
#   'position': {'id': 13, 'name': 'Right Center Midfield'},
#   'teammate': False},
#  {'location': [91.9, 51.4],
#   'player': {'id': 105392, 'name': 'Simon Adingra'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'teammate': False},
#  {'location': [117.4, 39.9],
#   'player': {'id': 36629, 'name': 'Yahia Fofana'},
#   'position': {'id': 1, 'name': 'Goalkeeper'},
#   'teammate': False},
#  {'location': [104.0, 28.3],
#   'player': {'id': 43779, 'name': 'Calvin Bassey Ughelumba'},
#   'position': {'id': 6, 'name': 'Left Back'},
#   'teammate': True},
#  {'location': [91.6, 33.4],
#   'player': {'id': 3856, 'name': 'Joe Aribo'},
#   'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#   'teammate': True},
#  {'location': [104.4, 36.1],
#   'player': {'id': 3923, 'name': 'Oluwasemilogo Adesewo Ibidapo Ajayi'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'teammate': True},
#  {'location': [107.3, 35.5],
#   'player': {'id': 34335, 'name': 'Terem Igobor Moffi'},
#   'position': {'id': 19, 'name': 'Center Attacking Midfield'},
#   'teammate': True},
#  {'location': [106.2, 41.6],
#   'player': {'id': 5455, 'name': 'William Troost-Ekong'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'teammate': True},
#  {'location': [97.3, 38.4],
#   'player': {'id': 18163, 'name': 'Moses Daddy-Ajala Simon'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'teammate': True},
#  {'location': [110.3, 43.4],
#   'player': {'id': 11277, 'name': 'Victor James Osimhen'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'teammate': True},
#  {'location': [85.1, 51.6],
#   'player': {'id': 11492, 'name': 'Temitayo Olufisayo Olaoluwa Aina'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'teammate': True},
#  {'location': [97.4, 52.4],
#   'player': {'id': 3708, 'name': 'Kelechi Promise Iheanacho'},
#   'position': {'id': 17, 'name': 'Right Wing'},
#   'teammate': True}]

# %%
df_freeze = pd.DataFrame(df_shot.shot_freeze_frame)

# %%
df_freeze
# Out:
#          location                                             player  \
# 0   [102.8, 43.1]      {'id': 43072, 'name': 'Jean-Philippe Krasso'}
# 1   [109.7, 39.2]   {'id': 36539, 'name': 'Wilfried Stephane Singo'}
# 2   [107.4, 44.2]          {'id': 7713, 'name': 'Obite Evan Ndicka'}
# 3   [109.8, 42.0]           {'id': 27133, 'name': 'Odilon Kossonou'}
# 4   [108.9, 49.1]            {'id': 10039, 'name': 'Ghislain Konan'}
# 5   [104.2, 49.8]      {'id': 7023, 'name': 'Franck Yannick Kessié'}
# 6   [105.0, 39.7]            {'id': 3017, 'name': 'Ibrahim Sangaré'}
# 7   [102.4, 30.0]            {'id': 212489, 'name': 'Oumar Diakité'}
# 8    [94.7, 40.7]  {'id': 23957, 'name': 'Jean Thierry Lazare Ama...
# 9    [91.9, 51.4]            {'id': 105392, 'name': 'Simon Adingra'}
# 10  [117.4, 39.9]              {'id': 36629, 'name': 'Yahia Fofana'}
# 11  [104.0, 28.3]   {'id': 43779, 'name': 'Calvin Bassey Ughelumba'}
# 12   [91.6, 33.4]                  {'id': 3856, 'name': 'Joe Aribo'}
# 13  [104.4, 36.1]  {'id': 3923, 'name': 'Oluwasemilogo Adesewo Ib...
# 14  [107.3, 35.5]        {'id': 34335, 'name': 'Terem Igobor Moffi'}
# 15  [106.2, 41.6]       {'id': 5455, 'name': 'William Troost-Ekong'}
# 16   [97.3, 38.4]   {'id': 18163, 'name': 'Moses Daddy-Ajala Simon'}
# 17  [110.3, 43.4]      {'id': 11277, 'name': 'Victor James Osimhen'}
# 18   [85.1, 51.6]  {'id': 11492, 'name': 'Temitayo Olufisayo Olao...
# 19   [97.4, 52.4]  {'id': 3708, 'name': 'Kelechi Promise Iheanacho'}
#
#                                            position  teammate
# 0              {'id': 23, 'name': 'Center Forward'}     False
# 1                   {'id': 2, 'name': 'Right Back'}     False
# 2             {'id': 5, 'name': 'Left Center Back'}     False
# 3            {'id': 3, 'name': 'Right Center Back'}     False
# 4                    {'id': 6, 'name': 'Left Back'}     False
# 5        {'id': 15, 'name': 'Left Center Midfield'}     False
# 6   {'id': 10, 'name': 'Center Defensive Midfield'}     False
# 7                  {'id': 17, 'name': 'Right Wing'}     False
# 8       {'id': 13, 'name': 'Right Center Midfield'}     False
# 9                   {'id': 21, 'name': 'Left Wing'}     False
# 10                  {'id': 1, 'name': 'Goalkeeper'}     False
# 11                   {'id': 6, 'name': 'Left Back'}      True
# 12    {'id': 11, 'name': 'Left Defensive Midfield'}      True
# 13           {'id': 3, 'name': 'Right Center Back'}      True
# 14  {'id': 19, 'name': 'Center Attacking Midfield'}      True
# 15            {'id': 5, 'name': 'Left Center Back'}      True
# 16                  {'id': 21, 'name': 'Left Wing'}      True
# 17             {'id': 23, 'name': 'Center Forward'}      True
# 18                  {'id': 2, 'name': 'Right Back'}      True
# 19                 {'id': 17, 'name': 'Right Wing'}      True

# %%
highlight_players = ["Alhassan Yusuf"]

# %%
pitch = VerticalPitch(
    pitch_type="statsbomb",
    half=True
)

fig, ax = pitch.draw()

shot_x, shot_y = df_shot.location

pitch.scatter(
    shot_x, shot_y,
    marker="football",
    s=50, alpha=0.7, zorder=999,
    ax=ax
)

pitch.lines(
    shot_x, shot_y, 120, 36,
    color="red", linestyle="--", linewidth=1,
    ax=ax
)
pitch.lines(
    shot_x, shot_y, 120, 44,
    color="red", linestyle="--", linewidth=1,
    ax=ax
)

pitch.goal_angle(
    shot_x, shot_y, alpha=0.2, zorder=1.1,
    color='#cb5a4c', goal='right',
    ax=ax
)

for row in df_freeze.itertuples():

    player_x, player_y = row.location
    position = row.position

    if position["name"] == "Goalkeeper":
        pitch.scatter(
            player_x, player_y,
            c="black", s=20, alpha=0.7,
            ax=ax
        )
    else:
        pitch.scatter(
            player_x, player_y,
            c="silver" if row.teammate else "red", s=20, alpha=0.7,
            ax=ax
        )

    if row.teammate:
        player_name = row.player["name"]        
        if player_name in highlight_players:
            pitch.annotate(player_name, (player_x, player_y - 15), ax=ax)

plt.show()
