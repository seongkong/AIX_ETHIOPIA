# %% [markdown]
# # Practice-Session 2

# %% [markdown]
# ## What is the Season_id of the African Cup of Nations?

# %%
import os
from statsbombpy import sb
import warnings
warnings.filterwarnings("ignore", message="credentials were not supplied")

# %%
df_competitions = sb.competitions()

# %%
df_competitions.head()
# Out:
#    competition_id  season_id country_name        competition_name  \
# 0               9        281      Germany           1. Bundesliga
# 1               9         27      Germany           1. Bundesliga
# 2            1267        107       Africa  African Cup of Nations
# 3              16          4       Europe        Champions League
# 4              16          1       Europe        Champions League
#
#   competition_gender  competition_youth  competition_international  \
# 0               male              False                      False
# 1               male              False                      False
# 2               male              False                       True
# 3               male              False                      False
# 4               male              False                      False
#
#   season_name               match_updated           match_updated_360  \
# 0   2023/2024  2024-09-28T20:46:38.893391  2025-07-06T04:26:07.636270
# ...

# %%
df_African_Cup = df_competitions[ df_competitions.competition_name == "African Cup of Nations" ]
df_African_Cup
# Out:
#    competition_id  season_id country_name        competition_name  \
# 2            1267        107       Africa  African Cup of Nations
#
#   competition_gender  competition_youth  competition_international  \
# 2               male              False                       True
#
#   season_name               match_updated match_updated_360  \
# 2        2023  2024-09-28T01:57:35.846538              None
#
#   match_available_360             match_available
# 2                None  2024-09-28T01:57:35.846538

# %%
df_matches = sb.matches(
    competition_id=1267,
    season_id=107,
)

# %%
df_matches.head()
# Out:
#    match_id  match_date      kick_off                      competition season  \
# 0   3923881  2024-02-11  22:00:00.000  Africa - African Cup of Nations   2023
# 1   3923880  2024-02-10  22:00:00.000  Africa - African Cup of Nations   2023
# 2   3922838  2024-02-07  22:00:00.000  Africa - African Cup of Nations   2023
# 3   3922837  2024-02-07  19:00:00.000  Africa - African Cup of Nations   2023
# 4   3922242  2024-01-29  22:00:00.000  Africa - African Cup of Nations   2023
#
#        home_team      away_team  home_score  away_score match_status  ...  \
# 0        Nigeria  Côte d'Ivoire           1           2    available  ...
# 1   South Africa       Congo DR           0           0    available  ...
# 2  Côte d'Ivoire       Congo DR           1           0    available  ...
# 3        Nigeria   South Africa           1           1    available  ...
# 4        Senegal  Côte d'Ivoire           1           1    available  ...
#
#   last_updated_360 match_week competition_stage  \
# ...

# %% [markdown]
# ## Name three players who played in the final match of the African Cup of Nations.

# %%
df_events = sb.events(match_id=3923881)

# %%
print(df_events['player'].dropna())
# Out:
# 6                           Ademola Lookman
# 7                      William Troost-Ekong
# 8                   Calvin Bassey Ughelumba
# 9       Oluwasemilogo Adesewo Ibidapo Ajayi
# 10                             Yahia Fofana
#                        ...
# 2690                           Frank Onyeka
# 2691                           Zaidu Sanusi
# 2692                       Sébastien Haller
# 2693                            Seko Fofana
# 2694                      Jean Michaël Seri
# Name: player, Length: 2676, dtype: object
