# %% [markdown]
# *Copyright 2024 Jaeyoung Chun*
#
# You may not make copies of this and use or distribute it for any purpose.

# %% [markdown]
# # Shot and Pass

# %%
import matplotlib.pyplot as plt
from mplsoccer import Pitch

# %% [markdown]
# **Requirements**
#
# Coordinates:
#
# - Son at `x=40`, `y=60`.
# - Messi at `x=100`, `y=25`.
# - Goal scored at `x=120`, `y=42`.

# %% [markdown]
# <img src="./img/son-to-messi.png"/>

# %%
pitch = Pitch()

fig, ax = pitch.draw()

# ---------------------------
# Write your code below
# ---------------------------

plt.show()
